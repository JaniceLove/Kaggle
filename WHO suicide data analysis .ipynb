# %% [markdown]
# ## WHO suicide statistics
# WHO suicide statistics-worldwide
# Kaggle dataset: https://www.kaggle.com/szamil/who-suicide-statistics/kernels

# %% [markdown]
# ## Things to examine in data set:
# - total suicides per year (Have have worldwide suicide rates changed over time?)
# - total suicides per country
# - total suicides: male vs female
# - total suicides per age group
# - age group vs gender
# -

# %%
import pandas as pd
from plotnine import *
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('who_suicide_statistics.csv', sep=',')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0

# %%
df['rate_per_100k'] = df['suicides_no'] / (df['population'] / 100000)

# %%
age_s = sns.barplot(x='age',y='suicides_no',data=df, palette='BuGn_r',
                order=['5-14 years','15-24 years','25-34 years','35-54 years',
                      '55-74 years','75+ years'])

age_s.set_xlabel('Age')
age_s.set_ylabel('Number of Suicides')
age_s.set_title('Number of Suicides per Age Group')
sns.plt.show()

# %%
age_s = sns.barplot(x='age',y='rate_per_100k',data=df, palette='BuGn_r',
                order=['5-14 years','15-24 years','25-34 years','35-54 years',
                      '55-74 years','75+ years'])

age_s.set_xlabel('Age')
age_s.set_ylabel('Number of Suicides per 100k population')
age_s.set_title('Number of Suicides per Age Group')
sns.plt.show()

# %%
gender_s = sns.barplot(x='sex', y='suicides_no', data=df)
gender_s.set_xticklabels(gender_s.get_xticklabels())
gender_s.set_xlabel=('Sex')
gender_s.set_ylabel=('Number of Suicides')
gender_s.set_title("Number of Suicides per Sex")
sns.plt.show()
#Fix y label

# %%
gender_s = sns.barplot(x='sex', y='rate_per_100k', data=df)
gender_s.set_xticklabels(gender_s.get_xticklabels())
gender_s.set_xlabel=('Sex')
gender_s.set_ylabel=('Number of Suicides per 100k')
gender_s.set_title("Number of Suicides per Sex")
sns.plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-49-35cb8d5a0173> in <module>()
#       4 gender_s.set_ylabel=('Number of Suicides per 100k')
#       5 gender_s.set_title("Number of Suicides per Sex")
# ----> 6 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
year_s = sns.barplot(x='year',y='suicides_no',data=df, palette='BuGn_r')
                
year_s.set_xticklabels(year_s.get_xticklabels(), rotation=90)
year_s.set_xlabel('Year')
year_s.set_ylabel('Number of Suicides')
year_s.set_title('Number of Suicides per Year')
sns.plt.show()

# %%
year_s = sns.barplot(x='year',y='rate_per_100k',data=df, palette='BuGn_r')
                
year_s.set_xticklabels(year_s.get_xticklabels(), rotation=90)
year_s.set_xlabel('Year')
year_s.set_ylabel('Number of Suicides per 100k population')
year_s.set_title('Number of Suicides per Year Worldwide')
sns.plt.show()

# %%
df.describe()
# Out:
#                year   suicides_no    population  rate_per_100k
# count  43776.000000  41520.000000  3.831600e+04   36060.000000
# mean    1998.502467    193.315390  1.664091e+06      13.185094
# std       10.338711    800.589926  3.647231e+06      19.902566
# min     1979.000000      0.000000  2.590000e+02       0.000000
# 25%     1990.000000      1.000000  8.511275e+04       0.781784
# 50%     1999.000000     14.000000  3.806550e+05       5.975607
# 75%     2007.000000     91.000000  1.305698e+06      17.010064
# max     2016.000000  22338.000000  4.380521e+07     300.751880

# %% [markdown]
# ## Conclusions:
# - Men comprise the majority of suicides worldwide. (Probably because they are more likely to be successful, as reported elsewhere)
# - The year 2016 had a huge drop in the number of suicides
# - The age group with the greatest number of suicides is 35-54 years old.

# %% [markdown]
# # Now let's look at data for USA only

# %%
usa_df = df.loc[df['country']=='United States of America',]
usa_df.reset_index(drop=True,inplace=True)

# %%
usa_df.head()
# Out:
#                     country  year     sex          age  suicides_no  \
# 0  United States of America  1979  female  15-24 years       1001.0
# 1  United States of America  1979  female  25-34 years       1352.0
# 2  United States of America  1979  female  35-54 years       2458.0
# 3  United States of America  1979  female   5-14 years         48.0
# 4  United States of America  1979  female  55-74 years       1705.0
#
#    population  rate_per_100k
# 0  21039000.0       4.757831
# 1  18176000.0       7.438380
# 2  24669000.0       9.963922
# 3  17317000.0       0.277184
# 4  20097000.0       8.483853

# %%
usa_df.tail()
# Out:
#                       country  year   sex          age  suicides_no  \
# 451  United States of America  2016  male  25-34 years          NaN
# 452  United States of America  2016  male  35-54 years          NaN
# 453  United States of America  2016  male   5-14 years          NaN
# 454  United States of America  2016  male  55-74 years          NaN
# 455  United States of America  2016  male    75+ years          NaN
#
#      population  rate_per_100k
# 451  22511217.0            NaN
# 452  41481607.0            NaN
# 453  21313304.0            NaN
# 454  33121620.0            NaN
# 455   8423833.0            NaN

# %%
usa_age_s = sns.barplot(x='age',y='rate_per_100k',data=usa_df, palette='BuGn_r',
                order=['5-14 years','15-24 years','25-34 years','35-54 years',
                      '55-74 years','75+ years'])
usa_age_s.set_xticklabels(usa_age_s.get_xticklabels(), rotation=30)
usa_age_s.set_xlabel('Age')
usa_age_s.set_ylabel('Number of Suicides per 100k')
usa_age_s.set_title('Number of Suicides per Age Group in the USA: 1979-2015')
sns.plt.show()
# Out:
# /home/janicelove/anaconda2/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# AttributeErrorTraceback (most recent call last)
# <ipython-input-5-f3f1387dcdf7> in <module>()
#       6 usa_age_s.set_ylabel('Number of Suicides per 100k')
#       7 usa_age_s.set_title('Number of Suicides per Age Group in the USA: 1979-2015')
# ----> 8 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
#ugly, fix plot
sns.set_style("whitegrid")
g=sns.catplot(x="sex",y="rate_per_100k", hue="age", kind="bar", data=usa_df).set_xticklabels(rotation=90)
(g.fig.suptitle('Number of suicides per 100k: USA'))
# Out:
# Text(0.5,0.98,'Number of suicides per 100k: USA')

# %%
sns.set_style("whitegrid")
usa_year_s = sns.barplot(x='year',y='rate_per_100k',data=df, palette='BuGn_r')
                
usa_year_s.set_xticklabels(usa_year_s.get_xticklabels(), rotation=90)
usa_year_s.set_xlabel('Year')
usa_year_s.set_ylabel('Number of Suicides per 100k people')
usa_year_s.set_title('Number of Suicides per Year: USA')
sns.plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-18-f779c9c57e7a> in <module>()
#       6 usa_year_s.set_ylabel('Number of Suicides per 100k people')
#       7 usa_year_s.set_title('Number of Suicides per Year: USA')
# ----> 8 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
usa_decades = usa_df.loc[usa_df['year'].isin(['1985', '1995', '2005', '2015'])]

# %%
usa_decades.head()
# Out:
#                      country  year     sex          age  suicides_no  \
# 72  United States of America  1985  female  15-24 years        854.0
# 73  United States of America  1985  female  25-34 years       1242.0
# 74  United States of America  1985  female  35-54 years       2105.0
# 75  United States of America  1985  female   5-14 years         73.0
# 76  United States of America  1985  female  55-74 years       1568.0
#
#     population  rate_per_100k
# 72  19589000.0       4.359590
# 73  21041000.0       5.902761
# 74  27763000.0       7.582034
# 75  16553000.0       0.441008
# 76  21366000.0       7.338763

# %%
sns.set_style("whitegrid")
g=sns.catplot(x="age",y="rate_per_100k",  col='sex', hue="year", kind="bar", data=usa_decades,order=['5-14 years','15-24 years','25-34 years','35-54 years',
                      '55-74 years','75+ years']).set_xticklabels(rotation=90)

(g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
sns.plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-48-d57768c35e55> in <module>()
#       4
#       5 (g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
# ----> 6 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
p=sns.lineplot(x='year', y='rate_per_100k', data=usa_decades)

# %%
sns.set_style("whitegrid")
g=sns.catplot(x="age",y="rate_per_100k",  col='sex', hue="year", kind="point", data=usa_decades,order=['5-14 years','15-24 years','25-34 years','35-54 years',
                      '55-74 years','75+ years']).set_xticklabels(rotation=90)

(g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
sns.plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-56-3a1497dd0fa7> in <module>()
#       4
#       5 (g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
# ----> 6 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
sns.set_style("whitegrid")
g=sns.catplot(x="year",y="rate_per_100k",  col='sex', hue="age", kind="point", data=usa_decades).set_xticklabels(rotation=90)

(g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
sns.plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-58-ccce8a095b43> in <module>()
#       3
#       4 (g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
# ----> 5 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
sns.set_style("whitegrid")
g=sns.catplot(x="year",y="rate_per_100k",  col='sex', hue="age", kind="point", data=usa_df).set_xticklabels(rotation=90)

(g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
sns.plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-59-bba3d56ff3d5> in <module>()
#       3
#       4 (g.despine(left=True),g.set_axis_labels("", "Number of Suicides per 100k people"))
# ----> 5 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'
